# %%
import os

# %%
import pandas as pd

# %%
df = pd.read_json('./doid.json')

# %%
df.head
# Out:
# <bound method NDFrame.head of                                                graphs
# 0   {'nodes': [{'id': 'http://purl.obolibrary.org/...
# 1   {'nodes': [{'id': 'http://purl.obolibrary.org/...
# 2   {'nodes': [{'id': 'http://purl.obolibrary.org/...
# 3   {'nodes': [{'id': 'http://www.geneontology.org...
# 4   {'nodes': [{'id': 'http://purl.obolibrary.org/...
# 5   {'nodes': [{'id': 'http://purl.obolibrary.org/...
# 6   {'nodes': [{'id': 'http://purl.obolibrary.org/...
# 7   {'nodes': [{'id': 'http://purl.obolibrary.org/...
# 8   {'nodes': [{'id': 'http://purl.obolibrary.org/...
# 9   {'nodes': [{'id': 'http://purl.obolibrary.org/...
# 10  {'nodes': [{'id': 'http://purl.obolibrary.org/...
# 11  {'nodes': [{'id': 'http://purl.obolibrary.org/...
# 12  {'nodes': [{'id': 'http://purl.obolibrary.org/...
# 13  {'nodes': [{'id': 'http://purl.obolibrary.org/...
# 14  {'nodes': [{'id': 'http://purl.obolibrary.org/...>

# %%
pd.read_json()
# Out:
# {'nodes': [{'id': 'http://purl.obolibrary.org/obo/DOID_8718',
#    'meta': {'definition': {'val': 'A carcinoma in situ that is characterized by the spread of cancer in the respiratory system and the lack of invasion of surrounding tissues.',
#      'xrefs': ['url:http://en.wikipedia.org/wiki/Carcinoma_in_situ']},
#     'synonyms': [{'pred': 'hasExactSynonym',
#       'val': 'carcinoma in situ of respiratory tract (disorder)',
#       'xrefs': []}],
#     'basicPropertyValues': [{'pred': 'http://www.geneontology.org/formats/oboInOwl#hasAlternativeId',
#       'val': 'DOID:8965'},
#      {'pred': 'http://www.w3.org/2002/07/owl#deprecated', 'val': 'true'},
#      {'pred': 'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace',
#       'val': 'disease_ontology'}]},
#    'type': 'CLASS',
#    'lbl': 'obsolete carcinoma in situ of respiratory system'},
#   {'id': 'http://purl.obolibrary.org/obo/DOID_8717',
# ...
